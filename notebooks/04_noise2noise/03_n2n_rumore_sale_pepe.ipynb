# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from tqdm import tqdm

import cv2

from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim

import tensorflow as tf
from tensorflow.keras import layers, models
# Out:
# 2026-06-07 09:55:40.588594: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780826140.762331      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780826140.810386      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780826141.203997      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780826141.204041      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780826141.204043      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780826141.204046      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# # DATASET

# %%
# -----------------------------
# CLEAN DATASET
# -----------------------------

kodak_clean_dir = Path(
    "/kaggle/input/datasets/sherylmehta/kodak-dataset"
)

bsd500_clean_dir = Path(
    "/kaggle/input/datasets/balraj98/berkeley-segmentation-dataset-500-bsds500/images"
)

div2k_clean_base_dir = Path(
    "/kaggle/input/datasets/soumikrakshit/div2k-high-resolution-images"
)


# -----------------------------
# BSD500 CLEAN SPLIT
# -----------------------------

bsd500_train_clean_dir = bsd500_clean_dir / "train"
bsd500_val_clean_dir   = bsd500_clean_dir / "val"
bsd500_test_clean_dir  = bsd500_clean_dir / "test"


# -----------------------------
# DIV2K CLEAN SPLIT
# -----------------------------

div2k_train_clean_dir = div2k_clean_base_dir / "DIV2K_train_HR" / "DIV2K_train_HR"
div2k_valid_clean_dir = div2k_clean_base_dir / "DIV2K_valid_HR" / "DIV2K_valid_HR"

# %%
# -----------------------------
# OUTPUT NOISY DATASET FOR N2N
# SALT & PEPPER, amount = 0.05
# -----------------------------

n2n_saltpepper_base_dir = Path(
    "/kaggle/working/n2n_saltpepper_amount005_datasets"
)

# Kodak
kodak_noisy1_dir = n2n_saltpepper_base_dir / "kodak" / "noisy1"
kodak_noisy2_dir = n2n_saltpepper_base_dir / "kodak" / "noisy2"

# BSD500
bsd500_noisy1_dir = n2n_saltpepper_base_dir / "bsd500" / "noisy1"
bsd500_noisy2_dir = n2n_saltpepper_base_dir / "bsd500" / "noisy2"

# DIV2K
div2k_noisy1_base_dir = n2n_saltpepper_base_dir / "div2k" / "noisy1"
div2k_noisy2_base_dir = n2n_saltpepper_base_dir / "div2k" / "noisy2"


# -----------------------------
# OUTPUT MODEL / DENOISED
# -----------------------------

n2n_output_dir = Path(
    "/kaggle/working/n2n_saltpepper_amount005_outputs"
)

n2n_output_dir.mkdir(parents=True, exist_ok=True)

# %%
def get_image_paths(input_dir):
    """
    Restituisce tutti i path delle immagini contenute in input_dir,
    includendo eventuali sottocartelle.
    """

    input_dir = Path(input_dir)

    image_extensions = [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]

    image_paths = [
        p for p in input_dir.rglob("*")
        if p.suffix.lower() in image_extensions
    ]

    return sorted(image_paths)

# %%
def add_salt_pepper_noise(image, amount=0.05, salt_vs_pepper=0.5, seed=None):
    """
    Aggiunge rumore sale e pepe classico.

    image: immagine uint8 in [0, 255]
    amount: percentuale totale di pixel corrotti
            amount=0.01 -> 1% dei pixel corrotti
            amount=0.05 -> 5% dei pixel corrotti
            amount=0.10 -> 10% dei pixel corrotti

    salt_vs_pepper: proporzione tra sale e pepe
                    0.5 -> metà bianchi e metà neri

    seed: seme opzionale per rendere il risultato riproducibile

    Per immagini grayscale:
        i pixel corrotti diventano 0 oppure 255.

    Per immagini a colori:
        l'intero pixel diventa [0, 0, 0] oppure [255, 255, 255].
        Quindi il rumore appare realmente bianco e nero.

    Ritorna:
        noisy_image: immagine uint8 in [0, 255]
    """

    rng = np.random.default_rng(seed)

    noisy_image = image.copy()

    height, width = image.shape[:2]

    # Matrice casuale per decidere quali pixel corrompere
    rand = rng.random((height, width))

    pepper_threshold = amount * (1 - salt_vs_pepper)
    salt_threshold = amount

    pepper_mask = rand < pepper_threshold
    salt_mask = (rand >= pepper_threshold) & (rand < salt_threshold)

    # Pepe: pixel neri
    noisy_image[pepper_mask] = 0

    # Sale: pixel bianchi
    noisy_image[salt_mask] = 255

    return noisy_image

# %%
def create_saltpepper_n2n_pair_dataset(
    input_dir,
    output_dir_noisy1,
    output_dir_noisy2,
    amount=0.05,
    salt_vs_pepper=0.5,
    seed1=42,
    seed2=123
):
    """
    Crea due versioni rumorose indipendenti dello stesso dataset clean
    usando rumore sale e pepe.

    Noise2Noise:
        input  = noisy1
        target = noisy2

    Le due versioni hanno lo stesso valore di amount, ma maschere
    casuali indipendenti grazie a seed differenti.
    """

    input_dir = Path(input_dir)
    output_dir_noisy1 = Path(output_dir_noisy1)
    output_dir_noisy2 = Path(output_dir_noisy2)

    output_dir_noisy1.mkdir(parents=True, exist_ok=True)
    output_dir_noisy2.mkdir(parents=True, exist_ok=True)

    image_paths = get_image_paths(input_dir)

    print("Cartella input clean:", input_dir)
    print("Output noisy1:", output_dir_noisy1)
    print("Output noisy2:", output_dir_noisy2)
    print("Salt & Pepper amount:", amount)
    print("Salt vs pepper:", salt_vs_pepper)
    print("Immagini trovate:", len(image_paths))

    psnr_values_noisy1 = []
    psnr_values_noisy2 = []
    ssim_values_noisy1 = []
    ssim_values_noisy2 = []
    processed_images = []

    for idx, img_path in enumerate(tqdm(image_paths)):

        image = cv2.imread(str(img_path), cv2.IMREAD_COLOR)

        if image is None:
            print("Immagine non letta:", img_path)
            continue

        noisy1 = add_salt_pepper_noise(
            image=image,
            amount=amount,
            salt_vs_pepper=salt_vs_pepper,
            seed=seed1 + idx
        )

        noisy2 = add_salt_pepper_noise(
            image=image,
            amount=amount,
            salt_vs_pepper=salt_vs_pepper,
            seed=seed2 + idx
        )

        relative_path = img_path.relative_to(input_dir)

        save_path_noisy1 = output_dir_noisy1 / relative_path
        save_path_noisy2 = output_dir_noisy2 / relative_path

        save_path_noisy1.parent.mkdir(parents=True, exist_ok=True)
        save_path_noisy2.parent.mkdir(parents=True, exist_ok=True)

        success1 = cv2.imwrite(str(save_path_noisy1), noisy1)
        success2 = cv2.imwrite(str(save_path_noisy2), noisy2)

        if not success1:
            print("Errore nel salvataggio noisy1:", save_path_noisy1)
            continue

        if not success2:
            print("Errore nel salvataggio noisy2:", save_path_noisy2)
            continue

        psnr_values_noisy1.append(
            psnr(image, noisy1, data_range=255)
        )

        psnr_values_noisy2.append(
            psnr(image, noisy2, data_range=255)
        )

        ssim_values_noisy1.append(
            ssim(
                image,
                noisy1,
                channel_axis=2,
                data_range=255
            )
        )

        ssim_values_noisy2.append(
            ssim(
                image,
                noisy2,
                channel_axis=2,
                data_range=255
            )
        )

        processed_images.append(img_path.name)

    print("Immagini processate:", len(processed_images))

    if len(psnr_values_noisy1) > 0:
        print(
            "PSNR medio clean/noisy1:",
            np.mean(psnr_values_noisy1)
        )
        print(
            "PSNR medio clean/noisy2:",
            np.mean(psnr_values_noisy2)
        )
        print(
            "SSIM medio clean/noisy1:",
            np.mean(ssim_values_noisy1)
        )
        print(
            "SSIM medio clean/noisy2:",
            np.mean(ssim_values_noisy2)
        )

    return {
        "image_paths": image_paths,
        "processed_images": processed_images,
        "psnr_noisy1": psnr_values_noisy1,
        "psnr_noisy2": psnr_values_noisy2,
        "ssim_noisy1": ssim_values_noisy1,
        "ssim_noisy2": ssim_values_noisy2,
    }

# %%
kodak_generation_results = create_saltpepper_n2n_pair_dataset(
    input_dir=kodak_clean_dir,
    output_dir_noisy1=kodak_noisy1_dir,
    output_dir_noisy2=kodak_noisy2_dir,
    amount=0.05,
    salt_vs_pepper=0.5,
    seed1=42,
    seed2=123
)
# Out:
# Cartella input clean: /kaggle/input/datasets/sherylmehta/kodak-dataset
# Output noisy1: /kaggle/working/n2n_saltpepper_amount005_datasets/kodak/noisy1
# Output noisy2: /kaggle/working/n2n_saltpepper_amount005_datasets/kodak/noisy2
# Salt & Pepper amount: 0.05
# Salt vs pepper: 0.5
# Immagini trovate: 24
# 100%|██████████| 24/24 [00:11<00:00,  2.05it/s]
# Immagini processate: 24
# PSNR medio clean/noisy1: 18.149210813893614
# PSNR medio clean/noisy2: 18.144258072793377
# SSIM medio clean/noisy1: 0.37939031519028443
# SSIM medio clean/noisy2: 0.3789693427984037

# %%
bsd500_generation_results = create_saltpepper_n2n_pair_dataset(
    input_dir=bsd500_clean_dir,
    output_dir_noisy1=bsd500_noisy1_dir,
    output_dir_noisy2=bsd500_noisy2_dir,
    amount=0.05,
    salt_vs_pepper=0.5,
    seed1=42,
    seed2=123
)
# Out:
# Cartella input clean: /kaggle/input/datasets/balraj98/berkeley-segmentation-dataset-500-bsds500/images
# Output noisy1: /kaggle/working/n2n_saltpepper_amount005_datasets/bsd500/noisy1
# Output noisy2: /kaggle/working/n2n_saltpepper_amount005_datasets/bsd500/noisy2
# Salt & Pepper amount: 0.05
# Salt vs pepper: 0.5
# Immagini trovate: 500
# 100%|██████████| 500/500 [01:07<00:00,  7.46it/s]
# Immagini processate: 500
# PSNR medio clean/noisy1: 17.997814060095862
# PSNR medio clean/noisy2: 17.999089614461656
# SSIM medio clean/noisy1: 0.425361335648511
# SSIM medio clean/noisy2: 0.42540449640436545

# %%
div2k_train_generation_results = create_saltpepper_n2n_pair_dataset(
    input_dir=div2k_train_clean_dir,
    output_dir_noisy1=div2k_noisy1_base_dir / "DIV2K_train_HR",
    output_dir_noisy2=div2k_noisy2_base_dir / "DIV2K_train_HR",
    amount=0.05,
    salt_vs_pepper=0.5,
    seed1=42,
    seed2=123
)
# Out:
# Cartella input clean: /kaggle/input/datasets/soumikrakshit/div2k-high-resolution-images/DIV2K_train_HR/DIV2K_train_HR
# Output noisy1: /kaggle/working/n2n_saltpepper_amount005_datasets/div2k/noisy1/DIV2K_train_HR
# Output noisy2: /kaggle/working/n2n_saltpepper_amount005_datasets/div2k/noisy2/DIV2K_train_HR
# Salt & Pepper amount: 0.05
# Salt vs pepper: 0.5
# Immagini trovate: 800
# 100%|██████████| 800/800 [35:53<00:00,  2.69s/it]
# Immagini processate: 800
# PSNR medio clean/noisy1: 17.778140431165554
# PSNR medio clean/noisy2: 17.777845876191368
# SSIM medio clean/noisy1: 0.38639278409052663
# SSIM medio clean/noisy2: 0.3863589052092199

# %%
div2k_valid_generation_results = create_saltpepper_n2n_pair_dataset(
    input_dir=div2k_valid_clean_dir,
    output_dir_noisy1=div2k_noisy1_base_dir / "DIV2K_valid_HR",
    output_dir_noisy2=div2k_noisy2_base_dir / "DIV2K_valid_HR",
    amount=0.05,
    salt_vs_pepper=0.5,
    seed1=2024,
    seed2=3024
)
# Out:
# Cartella input clean: /kaggle/input/datasets/soumikrakshit/div2k-high-resolution-images/DIV2K_valid_HR/DIV2K_valid_HR
# Output noisy1: /kaggle/working/n2n_saltpepper_amount005_datasets/div2k/noisy1/DIV2K_valid_HR
# Output noisy2: /kaggle/working/n2n_saltpepper_amount005_datasets/div2k/noisy2/DIV2K_valid_HR
# Salt & Pepper amount: 0.05
# Salt vs pepper: 0.5
# Immagini trovate: 100
# 100%|██████████| 100/100 [04:32<00:00,  2.73s/it]
# Immagini processate: 100
# PSNR medio clean/noisy1: 17.75997569452708
# PSNR medio clean/noisy2: 17.760825445327317
# SSIM medio clean/noisy1: 0.3903299790964674
# SSIM medio clean/noisy2: 0.39032627174497003

# %%
print("Kodak noisy1:", len(get_image_paths(kodak_noisy1_dir)))
print("Kodak noisy2:", len(get_image_paths(kodak_noisy2_dir)))

print("BSD500 noisy1:", len(get_image_paths(bsd500_noisy1_dir)))
print("BSD500 noisy2:", len(get_image_paths(bsd500_noisy2_dir)))

print("DIV2K train noisy1:", len(get_image_paths(div2k_noisy1_base_dir / "DIV2K_train_HR")))
print("DIV2K train noisy2:", len(get_image_paths(div2k_noisy2_base_dir / "DIV2K_train_HR")))

print("DIV2K valid noisy1:", len(get_image_paths(div2k_noisy1_base_dir / "DIV2K_valid_HR")))
print("DIV2K valid noisy2:", len(get_image_paths(div2k_noisy2_base_dir / "DIV2K_valid_HR")))
# Out:
# Kodak noisy1: 24
# Kodak noisy2: 24
# BSD500 noisy1: 500
# BSD500 noisy2: 500
# DIV2K train noisy1: 800
# DIV2K train noisy2: 800
# DIV2K valid noisy1: 100
# DIV2K valid noisy2: 100

# %%
def show_n2n_noisy_pair(clean_dir, noisy1_dir, noisy2_dir, index=0):
    """
    Visualizza una coppia Noise2Noise:
    - immagine clean originale
    - prima versione rumorosa noisy1
    - seconda versione rumorosa noisy2
    - differenza assoluta tra noisy1 e noisy2

    Serve per verificare graficamente che noisy1 e noisy2:
    - provengano dalla stessa immagine clean;
    - abbiano lo stesso tipo/livello di rumore;
    - siano due realizzazioni casuali diverse.
    """

    clean_dir = Path(clean_dir)
    noisy1_dir = Path(noisy1_dir)
    noisy2_dir = Path(noisy2_dir)

    noisy1_paths = get_image_paths(noisy1_dir)

    if len(noisy1_paths) == 0:
        print("Nessuna immagine trovata in noisy1_dir.")
        return

    if index >= len(noisy1_paths):
        print("Indice fuori range.")
        print("Numero immagini disponibili:", len(noisy1_paths))
        return

    noisy1_path = noisy1_paths[index]
    relative_path = noisy1_path.relative_to(noisy1_dir)

    noisy2_path = noisy2_dir / relative_path
    clean_path = clean_dir / relative_path

    print("Clean:", clean_path)
    print("Noisy1:", noisy1_path)
    print("Noisy2:", noisy2_path)

    if not clean_path.exists():
        print("Clean non trovata:", clean_path)
        return

    if not noisy2_path.exists():
        print("Noisy2 non trovata:", noisy2_path)
        return

    clean_img = Image.open(clean_path).convert("RGB")
    noisy1_img = Image.open(noisy1_path).convert("RGB")
    noisy2_img = Image.open(noisy2_path).convert("RGB")

    # Uniformo le dimensioni per sicurezza
    noisy1_img = noisy1_img.resize(clean_img.size)
    noisy2_img = noisy2_img.resize(clean_img.size)

    clean_np = np.array(clean_img).astype(np.float32) / 255.0
    noisy1_np = np.array(noisy1_img).astype(np.float32) / 255.0
    noisy2_np = np.array(noisy2_img).astype(np.float32) / 255.0

    diff_np = np.abs(noisy1_np - noisy2_np)

    psnr_noisy1 = psnr(clean_np, noisy1_np, data_range=1.0)
    psnr_noisy2 = psnr(clean_np, noisy2_np, data_range=1.0)

    ssim_noisy1 = ssim(clean_np, noisy1_np, channel_axis=2, data_range=1.0)
    ssim_noisy2 = ssim(clean_np, noisy2_np, channel_axis=2, data_range=1.0)

    plt.figure(figsize=(22, 6))

    plt.subplot(1, 4, 1)
    plt.imshow(clean_np)
    plt.title("Clean originale")
    plt.axis("off")

    plt.subplot(1, 4, 2)
    plt.imshow(noisy1_np)
    plt.title(
        f"Noisy1\n"
        f"PSNR: {psnr_noisy1:.2f} dB | SSIM: {ssim_noisy1:.4f}"
    )
    plt.axis("off")

    plt.subplot(1, 4, 3)
    plt.imshow(noisy2_np)
    plt.title(
        f"Noisy2\n"
        f"PSNR: {psnr_noisy2:.2f} dB | SSIM: {ssim_noisy2:.4f}"
    )
    plt.axis("off")


    plt.tight_layout()
    plt.show()

    print("PSNR clean/noisy1:", psnr_noisy1)
    print("PSNR clean/noisy2:", psnr_noisy2)
    print("SSIM clean/noisy1:", ssim_noisy1)
    print("SSIM clean/noisy2:", ssim_noisy2)

# %%
show_n2n_noisy_pair(
    clean_dir=kodak_clean_dir,
    noisy1_dir=kodak_noisy1_dir,
    noisy2_dir=kodak_noisy2_dir,
    index=0
)
# Out:
# Clean: /kaggle/input/datasets/sherylmehta/kodak-dataset/kodim01.png
# Noisy1: /kaggle/working/n2n_saltpepper_amount005_datasets/kodak/noisy1/kodim01.png
# Noisy2: /kaggle/working/n2n_saltpepper_amount005_datasets/kodak/noisy2/kodim01.png
# PSNR clean/noisy1: 18.47538107842236
# PSNR clean/noisy2: 18.520456104542465
# SSIM clean/noisy1: 0.5039156
# SSIM clean/noisy2: 0.5063723

# %% [markdown]
# ## Logica del dataset Noise2Noise: noisy1, noisy2, validation e test set
#
# Nel paradigma **Noise2Noise**, la rete non viene addestrata utilizzando immagini pulite come target.
# L'idea fondamentale è generare, a partire dalla stessa immagine originale, due versioni rumorose indipendenti:
#
# ```text
# clean image → noisy1
# clean image → noisy2
# ```
# Le due immagini **noisy1** e **noisy2** rappresentano lo stesso contenuto visivo, ma contengono due realizzazioni diverse del rumore.
# Formalmente, si può scrivere:
#
# noisy1 = clean + n1
# noisy2 = clean + n2
#
# Durante il training, la rete riceve in input una patch estratta da noisy1 e deve predire la patch corrispondente estratta da noisy2:
#
# input  = patch noisy1
# target = patch noisy2
#
# La rete non vede mai l'immagine pulita durante l'addestramento.

# %%
# -----------------------------
# BSD500 noisy1/noisy2 split
# -----------------------------

bsd500_train_noisy1_dir = bsd500_noisy1_dir / "train"
bsd500_val_noisy1_dir   = bsd500_noisy1_dir / "val"
bsd500_test_noisy1_dir  = bsd500_noisy1_dir / "test"

bsd500_train_noisy2_dir = bsd500_noisy2_dir / "train"
bsd500_val_noisy2_dir   = bsd500_noisy2_dir / "val"
bsd500_test_noisy2_dir  = bsd500_noisy2_dir / "test"


# -----------------------------
# DIV2K noisy1/noisy2 split
# -----------------------------

div2k_train_noisy1_dir = div2k_noisy1_base_dir / "DIV2K_train_HR"
div2k_valid_noisy1_dir = div2k_noisy1_base_dir / "DIV2K_valid_HR"

div2k_train_noisy2_dir = div2k_noisy2_base_dir / "DIV2K_train_HR"
div2k_valid_noisy2_dir = div2k_noisy2_base_dir / "DIV2K_valid_HR"

# %%
bsd500_train_noisy1_paths = get_image_paths(bsd500_train_noisy1_dir)
bsd500_val_noisy1_paths   = get_image_paths(bsd500_val_noisy1_dir)

div2k_train_noisy1_paths = get_image_paths(div2k_train_noisy1_dir)[:200]
div2k_val_noisy1_paths   = get_image_paths(div2k_valid_noisy1_dir)[:20]

train_noisy1_paths = bsd500_train_noisy1_paths + div2k_train_noisy1_paths
val_noisy1_paths   = bsd500_val_noisy1_paths + div2k_val_noisy1_paths

print("Training images:", len(train_noisy1_paths))
print("Validation images:", len(val_noisy1_paths))
# Out:
# Training images: 400
# Validation images: 120

# %%
def get_corresponding_noisy2_path(noisy1_path, noisy1_root, noisy2_root):
    """
    Dato il path di una immagine noisy1, restituisce il path corrispondente
    della stessa immagine nella cartella noisy2.
    """

    noisy1_path = Path(noisy1_path)
    noisy1_root = Path(noisy1_root)
    noisy2_root = Path(noisy2_root)

    relative_path = noisy1_path.relative_to(noisy1_root)

    return noisy2_root / relative_path

# %%
def extract_paired_random_patches(
    noisy1_paths,
    noisy1_roots,
    noisy2_roots,
    patch_size=64,
    patches_per_image=10,
    seed=42
):
    """
    Estrae coppie di patch corrispondenti da noisy1 e noisy2.

    X = patch presa da noisy1
    Y = patch corrispondente presa da noisy2

    Queste coppie vengono usate per addestrare Noise2Noise:
        input  = X
        target = Y
    """

    rng = np.random.default_rng(seed)

    X_patches = []
    Y_patches = []

    for noisy1_path in tqdm(noisy1_paths):

        noisy1_path = Path(noisy1_path)

        matched_root = None
        matched_target_root = None

        # Capisce se l'immagine appartiene a BSD500 o DIV2K
        for root1, root2 in zip(noisy1_roots, noisy2_roots):
            try:
                noisy1_path.relative_to(root1)
                matched_root = Path(root1)
                matched_target_root = Path(root2)
                break
            except ValueError:
                continue

        if matched_root is None:
            print("Root non trovata per:", noisy1_path)
            continue

        noisy2_path = get_corresponding_noisy2_path(
            noisy1_path,
            matched_root,
            matched_target_root
        )

        if not noisy2_path.exists():
            print("Noisy2 non trovata:", noisy2_path)
            continue

        img1 = Image.open(noisy1_path).convert("RGB")
        img2 = Image.open(noisy2_path).convert("RGB")

        img1 = np.array(img1).astype(np.float32) / 255.0
        img2 = np.array(img2).astype(np.float32) / 255.0

        h, w, c = img1.shape

        if h < patch_size or w < patch_size:
            print("Immagine troppo piccola, saltata:", noisy1_path)
            continue

        for _ in range(patches_per_image):
            y = rng.integers(0, h - patch_size + 1)
            x = rng.integers(0, w - patch_size + 1)

            patch1 = img1[y:y + patch_size, x:x + patch_size, :]
            patch2 = img2[y:y + patch_size, x:x + patch_size, :]

            X_patches.append(patch1)
            Y_patches.append(patch2)

    X_patches = np.array(X_patches, dtype=np.float16)
    Y_patches = np.array(Y_patches, dtype=np.float16)

    print("X patches:", X_patches.shape)
    print("Y patches:", Y_patches.shape)

    return X_patches, Y_patches

# %%
X_train, Y_train = extract_paired_random_patches(
    noisy1_paths=train_noisy1_paths,
    noisy1_roots=[
        bsd500_train_noisy1_dir,
        div2k_train_noisy1_dir
    ],
    noisy2_roots=[
        bsd500_train_noisy2_dir,
        div2k_train_noisy2_dir
    ],
    patch_size=64,
    patches_per_image=5,
    seed=42
)

X_val, Y_val = extract_paired_random_patches(
    noisy1_paths=val_noisy1_paths,
    noisy1_roots=[
        bsd500_val_noisy1_dir,
        div2k_valid_noisy1_dir
    ],
    noisy2_roots=[
        bsd500_val_noisy2_dir,
        div2k_valid_noisy2_dir
    ],
    patch_size=64,
    patches_per_image=2,
    seed=123
)

print("X_train:", X_train.shape)
print("Y_train:", Y_train.shape)
print("X_val:", X_val.shape)
print("Y_val:", Y_val.shape)
# Out:
# 100%|██████████| 400/400 [00:47<00:00,  8.45it/s]
# X patches: (2000, 64, 64, 3)
# Y patches: (2000, 64, 64, 3)
# 100%|██████████| 120/120 [00:04<00:00, 29.71it/s]
# X patches: (240, 64, 64, 3)
# Y patches: (240, 64, 64, 3)
# X_train: (2000, 64, 64, 3)
# Y_train: (2000, 64, 64, 3)
# X_val: (240, 64, 64, 3)
# Y_val: (240, 64, 64, 3)

# %%
X_train = X_train.astype(np.float32)
Y_train = Y_train.astype(np.float32)
X_val = X_val.astype(np.float32)
Y_val = Y_val.astype(np.float32)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def conv_block(x, filters):
    x = layers.Conv2D(
        filters,
        kernel_size=3,
        padding="same",
        kernel_initializer="he_normal"
    )(x)
    x = layers.LeakyReLU(negative_slope=0.1)(x)

    x = layers.Conv2D(
        filters,
        kernel_size=3,
        padding="same",
        kernel_initializer="he_normal"
    )(x)
    x = layers.LeakyReLU(negative_slope=0.1)(x)

    return x


def build_n2n_unet(input_shape=(64, 64, 3), base_filters=32):
    inputs = layers.Input(shape=input_shape)

    c1 = conv_block(inputs, base_filters)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = conv_block(p1, base_filters * 2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = conv_block(p2, base_filters * 4)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    bottleneck = conv_block(p3, base_filters * 8)

    u3 = layers.UpSampling2D((2, 2))(bottleneck)
    u3 = layers.Concatenate()([u3, c3])
    c4 = conv_block(u3, base_filters * 4)

    u2 = layers.UpSampling2D((2, 2))(c4)
    u2 = layers.Concatenate()([u2, c2])
    c5 = conv_block(u2, base_filters * 2)

    u1 = layers.UpSampling2D((2, 2))(c5)
    u1 = layers.Concatenate()([u1, c1])
    c6 = conv_block(u1, base_filters)

    outputs = layers.Conv2D(
        3,
        kernel_size=1,
        padding="same",
        activation="sigmoid"
    )(c6)

    model = models.Model(inputs, outputs)

    return model

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath="/kaggle/working/n2n_saltpepper_amount005_mae_best.keras",
        monitor="val_loss",
        save_best_only=True,
        verbose=1
    ),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=3,
        min_lr=1e-6,
        verbose=1
    ),

    tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=6,
        restore_best_weights=True,
        verbose=1
    )
]

# %%
tf.keras.backend.clear_session()

model = build_n2n_unet(
    input_shape=(64, 64, 3),
    base_filters=32
)

model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=5e-5,
        beta_1=0.9,
        beta_2=0.99,
        epsilon=1e-8
    ),
    loss="mae",
    metrics=["mse"]
)

history = model.fit(
    X_train,
    Y_train,
    validation_data=(X_val, Y_val),
    epochs=40,
    batch_size=4,
    callbacks=callbacks,
    shuffle=True
)
# Out:
# I0000 00:00:1780828726.839784      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1780828726.846271      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Epoch 1/40
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780828732.347009      73 service.cc:152] XLA service 0x79bc54002fa0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780828732.347046      73 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780828732.347050      73 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780828733.090931      73 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-06-07 10:38:54.996360: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:38:55.138856: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  13/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.2372 - mse: 0.0799
# I0000 00:00:1780828738.861246      73 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 497/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1462 - mse: 0.0422
# Epoch 1: val_loss improved from inf to 0.09503, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - loss: 0.1460 - mse: 0.0421 - val_loss: 0.0950 - val_mse: 0.0254 - learning_rate: 5.0000e-05
# Epoch 2/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0858 - mse: 0.0229
# Epoch 2: val_loss improved from 0.09503 to 0.07609, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0858 - mse: 0.0229 - val_loss: 0.0761 - val_mse: 0.0201 - learning_rate: 5.0000e-05
# Epoch 3/40
# 497/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0782 - mse: 0.0211
# Epoch 3: val_loss improved from 0.07609 to 0.07287, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0782 - mse: 0.0211 - val_loss: 0.0729 - val_mse: 0.0193 - learning_rate: 5.0000e-05
# Epoch 4/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0715 - mse: 0.0198
# Epoch 4: val_loss improved from 0.07287 to 0.07149, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0715 - mse: 0.0198 - val_loss: 0.0715 - val_mse: 0.0193 - learning_rate: 5.0000e-05
# Epoch 5/40
# 497/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0694 - mse: 0.0193
# Epoch 5: val_loss improved from 0.07149 to 0.07040, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0694 - mse: 0.0193 - val_loss: 0.0704 - val_mse: 0.0188 - learning_rate: 5.0000e-05
# Epoch 6/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0659 - mse: 0.0189
# Epoch 6: val_loss improved from 0.07040 to 0.06634, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0659 - mse: 0.0189 - val_loss: 0.0663 - val_mse: 0.0182 - learning_rate: 5.0000e-05
# Epoch 7/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0639 - mse: 0.0186
# Epoch 7: val_loss improved from 0.06634 to 0.06437, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0639 - mse: 0.0186 - val_loss: 0.0644 - val_mse: 0.0182 - learning_rate: 5.0000e-05
# Epoch 8/40
# 497/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0633 - mse: 0.0185
# Epoch 8: val_loss improved from 0.06437 to 0.06309, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0633 - mse: 0.0185 - val_loss: 0.0631 - val_mse: 0.0181 - learning_rate: 5.0000e-05
# Epoch 9/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0619 - mse: 0.0184
# Epoch 9: val_loss did not improve from 0.06309
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0619 - mse: 0.0184 - val_loss: 0.0638 - val_mse: 0.0178 - learning_rate: 5.0000e-05
# Epoch 10/40
# 496/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0592 - mse: 0.0179
# Epoch 10: val_loss improved from 0.06309 to 0.06007, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0592 - mse: 0.0179 - val_loss: 0.0601 - val_mse: 0.0175 - learning_rate: 5.0000e-05
# Epoch 11/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0584 - mse: 0.0179
# Epoch 11: val_loss did not improve from 0.06007
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0584 - mse: 0.0179 - val_loss: 0.0620 - val_mse: 0.0176 - learning_rate: 5.0000e-05
# Epoch 12/40
# 496/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0579 - mse: 0.0178
# Epoch 12: val_loss improved from 0.06007 to 0.05832, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0579 - mse: 0.0178 - val_loss: 0.0583 - val_mse: 0.0173 - learning_rate: 5.0000e-05
# Epoch 13/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0567 - mse: 0.0177
# Epoch 13: val_loss improved from 0.05832 to 0.05677, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0567 - mse: 0.0177 - val_loss: 0.0568 - val_mse: 0.0171 - learning_rate: 5.0000e-05
# Epoch 14/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0553 - mse: 0.0176
# Epoch 14: val_loss did not improve from 0.05677
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0553 - mse: 0.0176 - val_loss: 0.0578 - val_mse: 0.0172 - learning_rate: 5.0000e-05
# Epoch 15/40
# 497/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0551 - mse: 0.0176
# Epoch 15: val_loss improved from 0.05677 to 0.05658, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0551 - mse: 0.0176 - val_loss: 0.0566 - val_mse: 0.0169 - learning_rate: 5.0000e-05
# Epoch 16/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0540 - mse: 0.0173
# Epoch 16: val_loss did not improve from 0.05658
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0540 - mse: 0.0173 - val_loss: 0.0570 - val_mse: 0.0167 - learning_rate: 5.0000e-05
# Epoch 17/40
# 497/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0533 - mse: 0.0172
# Epoch 17: val_loss improved from 0.05658 to 0.05351, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0533 - mse: 0.0172 - val_loss: 0.0535 - val_mse: 0.0167 - learning_rate: 5.0000e-05
# Epoch 18/40
# 497/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0526 - mse: 0.0173
# Epoch 18: val_loss improved from 0.05351 to 0.05293, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0526 - mse: 0.0173 - val_loss: 0.0529 - val_mse: 0.0166 - learning_rate: 5.0000e-05
# Epoch 19/40
# 495/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0516 - mse: 0.0172
# Epoch 19: val_loss improved from 0.05293 to 0.05247, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0516 - mse: 0.0172 - val_loss: 0.0525 - val_mse: 0.0165 - learning_rate: 5.0000e-05
# Epoch 20/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0510 - mse: 0.0171
# Epoch 20: val_loss improved from 0.05247 to 0.05148, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0510 - mse: 0.0171 - val_loss: 0.0515 - val_mse: 0.0165 - learning_rate: 5.0000e-05
# Epoch 21/40
# 496/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0501 - mse: 0.0169
# Epoch 21: val_loss improved from 0.05148 to 0.05108, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0501 - mse: 0.0169 - val_loss: 0.0511 - val_mse: 0.0164 - learning_rate: 5.0000e-05
# Epoch 22/40
# 495/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0498 - mse: 0.0168
# Epoch 22: val_loss improved from 0.05108 to 0.05034, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0498 - mse: 0.0168 - val_loss: 0.0503 - val_mse: 0.0164 - learning_rate: 5.0000e-05
# Epoch 23/40
# 497/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0487 - mse: 0.0169
# Epoch 23: val_loss improved from 0.05034 to 0.04998, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0487 - mse: 0.0169 - val_loss: 0.0500 - val_mse: 0.0162 - learning_rate: 5.0000e-05
# Epoch 24/40
# 494/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0486 - mse: 0.0168
# Epoch 24: val_loss improved from 0.04998 to 0.04944, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0486 - mse: 0.0168 - val_loss: 0.0494 - val_mse: 0.0161 - learning_rate: 5.0000e-05
# Epoch 25/40
# 495/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0481 - mse: 0.0167
# Epoch 25: val_loss improved from 0.04944 to 0.04833, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0481 - mse: 0.0167 - val_loss: 0.0483 - val_mse: 0.0162 - learning_rate: 5.0000e-05
# Epoch 26/40
# 496/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0470 - mse: 0.0167
# Epoch 26: val_loss did not improve from 0.04833
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0470 - mse: 0.0167 - val_loss: 0.0490 - val_mse: 0.0162 - learning_rate: 5.0000e-05
# Epoch 27/40
# 495/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0468 - mse: 0.0166
# Epoch 27: val_loss did not improve from 0.04833
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0468 - mse: 0.0166 - val_loss: 0.0498 - val_mse: 0.0164 - learning_rate: 5.0000e-05
# Epoch 28/40
# 495/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0463 - mse: 0.0166
# Epoch 28: val_loss improved from 0.04833 to 0.04685, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0463 - mse: 0.0166 - val_loss: 0.0468 - val_mse: 0.0159 - learning_rate: 5.0000e-05
# Epoch 29/40
# 497/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0458 - mse: 0.0165
# Epoch 29: val_loss improved from 0.04685 to 0.04640, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0458 - mse: 0.0165 - val_loss: 0.0464 - val_mse: 0.0160 - learning_rate: 5.0000e-05
# Epoch 30/40
# 497/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0449 - mse: 0.0164
# Epoch 30: val_loss did not improve from 0.04640
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0449 - mse: 0.0164 - val_loss: 0.0479 - val_mse: 0.0159 - learning_rate: 5.0000e-05
# Epoch 31/40
# 495/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0446 - mse: 0.0164
# Epoch 31: val_loss improved from 0.04640 to 0.04535, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0446 - mse: 0.0164 - val_loss: 0.0454 - val_mse: 0.0158 - learning_rate: 5.0000e-05
# Epoch 32/40
# 496/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0441 - mse: 0.0163
# Epoch 32: val_loss improved from 0.04535 to 0.04515, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0441 - mse: 0.0163 - val_loss: 0.0451 - val_mse: 0.0158 - learning_rate: 5.0000e-05
# Epoch 33/40
# 494/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0443 - mse: 0.0163
# Epoch 33: val_loss improved from 0.04515 to 0.04477, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0443 - mse: 0.0163 - val_loss: 0.0448 - val_mse: 0.0158 - learning_rate: 5.0000e-05
# Epoch 34/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0437 - mse: 0.0165
# Epoch 34: val_loss improved from 0.04477 to 0.04429, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0437 - mse: 0.0165 - val_loss: 0.0443 - val_mse: 0.0158 - learning_rate: 5.0000e-05
# Epoch 35/40
# 495/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0429 - mse: 0.0162
# Epoch 35: val_loss did not improve from 0.04429
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0429 - mse: 0.0162 - val_loss: 0.0448 - val_mse: 0.0158 - learning_rate: 5.0000e-05
# Epoch 36/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0428 - mse: 0.0162
# Epoch 36: val_loss improved from 0.04429 to 0.04394, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0428 - mse: 0.0162 - val_loss: 0.0439 - val_mse: 0.0157 - learning_rate: 5.0000e-05
# Epoch 37/40
# 497/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0427 - mse: 0.0162
# Epoch 37: val_loss improved from 0.04394 to 0.04369, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0427 - mse: 0.0162 - val_loss: 0.0437 - val_mse: 0.0156 - learning_rate: 5.0000e-05
# Epoch 38/40
# 498/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0420 - mse: 0.0162
# Epoch 38: val_loss improved from 0.04369 to 0.04331, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0420 - mse: 0.0162 - val_loss: 0.0433 - val_mse: 0.0156 - learning_rate: 5.0000e-05
# Epoch 39/40
# 497/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0420 - mse: 0.0161
# Epoch 39: val_loss improved from 0.04331 to 0.04276, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0420 - mse: 0.0161 - val_loss: 0.0428 - val_mse: 0.0156 - learning_rate: 5.0000e-05
# Epoch 40/40
# 496/500 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0416 - mse: 0.0161
# Epoch 40: val_loss improved from 0.04276 to 0.04246, saving model to /kaggle/working/n2n_saltpepper_amount005_mae_best.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0416 - mse: 0.0161 - val_loss: 0.0425 - val_mse: 0.0156 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 40.

# %%
def pad_to_multiple_of_8(img):
    """
    Aggiunge padding riflesso a un'immagine affinché altezza e larghezza
    siano divisibili per 8.

    Questo è necessario perché la U-Net usa 3 livelli di MaxPooling,
    quindi le dimensioni devono essere compatibili con 2^3 = 8.
    """

    h, w, c = img.shape

    pad_h = (8 - h % 8) % 8
    pad_w = (8 - w % 8) % 8

    padded = np.pad(
        img,
        ((0, pad_h), (0, pad_w), (0, 0)),
        mode="reflect"
    )

    return padded, h, w

# %%
def denoise_dataset_with_n2n(
    model,
    noisy_dir,
    clean_dir,
    output_dir,
    csv_name="metrics.csv"
):
    """
    Applica il modello Noise2Noise a tutte le immagini rumorose di noisy_dir,
    salva le immagini denoised in output_dir e calcola PSNR/SSIM rispetto
    alle immagini clean corrispondenti.

    Il modello riceve in input una immagine noisy1 e produce una versione denoised.
    Le immagini clean vengono usate solo per la valutazione finale.
    """

    noisy_dir = Path(noisy_dir)
    clean_dir = Path(clean_dir)
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    noisy_paths = get_image_paths(noisy_dir)

    results = []

    for noisy_path in tqdm(noisy_paths):
        try:
            relative_path = noisy_path.relative_to(noisy_dir)
            clean_path = clean_dir / relative_path

            if not clean_path.exists():
                print("Clean non trovata:", clean_path)
                continue

            # Lettura immagine rumorosa
            noisy_img = Image.open(noisy_path).convert("RGB")
            noisy_np = np.array(noisy_img).astype(np.float32) / 255.0

            # Predizione N2N
            noisy_padded, original_h, original_w = pad_to_multiple_of_8(noisy_np)

            input_tensor = np.expand_dims(noisy_padded, axis=0)

            pred_padded = model.predict(input_tensor, verbose=0)[0]

            pred = pred_padded[:original_h, :original_w, :]
            pred = np.clip(pred, 0, 1)

            # Salvataggio immagine denoised
            save_path = output_dir / relative_path
            save_path = save_path.with_suffix(".png")
            save_path.parent.mkdir(parents=True, exist_ok=True)

            Image.fromarray((pred * 255).astype(np.uint8)).save(save_path)

            # Lettura clean
            clean_img = Image.open(clean_path).convert("RGB")
            clean_img = clean_img.resize((noisy_np.shape[1], noisy_np.shape[0]))
            clean_np = np.array(clean_img).astype(np.float32) / 255.0

            # Metriche noisy
            psnr_noisy = psnr(clean_np, noisy_np, data_range=1.0)
            ssim_noisy = ssim(clean_np, noisy_np, channel_axis=2, data_range=1.0)

            # Metriche N2N
            psnr_n2n = psnr(clean_np, pred, data_range=1.0)
            ssim_n2n = ssim(clean_np, pred, channel_axis=2, data_range=1.0)

            results.append({
                "filename": str(relative_path),
                "clean_path": str(clean_path),
                "noisy_path": str(noisy_path),
                "denoised_path": str(save_path),
                "psnr_clean_noisy": float(psnr_noisy),
                "ssim_clean_noisy": float(ssim_noisy),
                "psnr_clean_n2n": float(psnr_n2n),
                "ssim_clean_n2n": float(ssim_n2n),
                "psnr_gain": float(psnr_n2n - psnr_noisy),
                "ssim_gain": float(ssim_n2n - ssim_noisy),
            })

        except Exception as e:
            print("Errore su:", noisy_path)
            print(e)

    df = pd.DataFrame(results)

    csv_path = output_dir / csv_name
    df.to_csv(csv_path, index=False)

    print("CSV salvato in:", csv_path)

    if len(df) > 0:
        print("PSNR medio clean/noisy:", df["psnr_clean_noisy"].mean())
        print("PSNR medio clean/N2N:", df["psnr_clean_n2n"].mean())
        print("Gain PSNR medio:", df["psnr_gain"].mean())

        print("SSIM medio clean/noisy:", df["ssim_clean_noisy"].mean())
        print("SSIM medio clean/N2N:", df["ssim_clean_n2n"].mean())
        print("Gain SSIM medio:", df["ssim_gain"].mean())

    return df

# %%
model_flexible = build_n2n_unet(
    input_shape=(None, None, 3),
    base_filters=32
)

model_flexible.set_weights(model.get_weights())

# %%
df_kodak_n2n = denoise_dataset_with_n2n(
    model=model_flexible,
    noisy_dir=kodak_noisy1_dir,
    clean_dir=kodak_clean_dir,
    output_dir=n2n_output_dir / "kodak",
    csv_name="kodak_saltpepper_amount005_n2n_metrics.csv"
)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]2026-06-07 10:41:58.563932: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:41:58.768919: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:41:59.352912: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:41:59.615992: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  12%|█▎        | 3/24 [00:07<00:37,  1.77s/it]2026-06-07 10:42:05.182356: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:42:05.390260: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:42:05.958089: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:42:06.222838: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 100%|██████████| 24/24 [00:22<00:00,  1.08it/s]
# CSV salvato in: /kaggle/working/n2n_saltpepper_amount005_outputs/kodak/kodak_saltpepper_amount005_n2n_metrics.csv
# PSNR medio clean/noisy: 18.14921077393401
# PSNR medio clean/N2N: 31.902847048749308
# Gain PSNR medio: 13.753636274815301
# SSIM medio clean/noisy: 0.37939029435316723
# SSIM medio clean/N2N: 0.9110145643353462
# Gain SSIM medio: 0.5316242625315984

# %%
df_bsd500_n2n = denoise_dataset_with_n2n(
    model=model_flexible,
    noisy_dir=bsd500_test_noisy1_dir,
    clean_dir=bsd500_test_clean_dir,
    output_dir=n2n_output_dir / "bsd500_test",
    csv_name="bsd500_test_saltpepper_amount005_n2n_metrics.csv"
)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]2026-06-07 10:42:19.939206: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:42:20.173116: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   2%|▎         | 5/200 [00:04<01:31,  2.12it/s]2026-06-07 10:42:23.999289: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:42:24.234606: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 100%|██████████| 200/200 [00:48<00:00,  4.12it/s]
# CSV salvato in: /kaggle/working/n2n_saltpepper_amount005_outputs/bsd500_test/bsd500_test_saltpepper_amount005_n2n_metrics.csv
# PSNR medio clean/noisy: 18.422514305975753
# PSNR medio clean/N2N: 31.114371293516623
# Gain PSNR medio: 12.691856987540874
# SSIM medio clean/noisy: 0.4361986891925335
# SSIM medio clean/N2N: 0.9079786145687103
# Gain SSIM medio: 0.47177992418408393

# %%
df_div2k_n2n = denoise_dataset_with_n2n(
    model=model_flexible,
    noisy_dir=div2k_valid_noisy1_dir,
    clean_dir=div2k_valid_clean_dir,
    output_dir=n2n_output_dir / "div2k_valid",
    csv_name="div2k_valid_saltpepper_amount005_n2n_metrics.csv"
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]2026-06-07 10:43:08.084687: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:08.243249: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:09.406169: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:09.633497: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:10.756547: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:10.932345: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:12.405398: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:12.619913: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:21.571087: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:21.908497: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:25.434012: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:25.805677: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   2%|▏         | 2/100 [00:25<18:15, 11.18s/it]2026-06-07 10:43:33.892503: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:34.056052: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:35.513017: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:35.752818: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:37.151480: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:37.333744: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:39.060499: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:39.281532: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:49.433146: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:49.786293: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:53.168526: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:53.562419: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:53.570842: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,1536,2040]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,1536,2040]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-07 10:43:53.616291: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.045544709s
# Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,1536,2040]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,1536,2040]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
#   3%|▎         | 3/100 [00:51<28:40, 17.74s/it]2026-06-07 10:43:59.270070: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:43:59.422944: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:44:00.549542: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:44:00.763785: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:44:13.313268: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:44:13.647102: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   6%|▌         | 6/100 [01:16<14:40,  9.37s/it]2026-06-07 10:44:24.700027: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:44:24.908352: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:44:37.096260: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:44:37.422231: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  12%|█▏        | 12/100 [01:48<06:43,  4.59s/it]2026-06-07 10:44:56.858533: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:44:57.021615: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:44:58.390843: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:44:58.621859: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:44:59.881528: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:00.062686: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:01.556496: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:01.774675: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:11.466592: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:11.815499: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:15.241534: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:15.625444: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:15.666527: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,1464,2040]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,1464,2040]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-07 10:45:15.679990: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.013573018s
# Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,1464,2040]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,1464,2040]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
#  21%|██        | 21/100 [02:37<04:24,  3.35s/it]2026-06-07 10:45:45.201237: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:45.363863: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:46.817090: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:47.057275: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:48.361896: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:48.545721: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:50.137484: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:45:50.361556: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:01.066177: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:01.432774: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:05.007850: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:05.380269: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,1600,2040]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,1600,2040]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-07 10:46:05.417746: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:05.472668: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.092509128s
# Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,1600,2040]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,1600,2040]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
#  22%|██▏       | 22/100 [03:03<13:17, 10.23s/it]2026-06-07 10:46:11.322644: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:11.480434: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:12.750834: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:12.973315: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:13.940904: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:14.115112: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:15.636830: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:15.848153: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:24.942384: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:25.267377: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:28.459721: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:28.809765: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  29%|██▉       | 29/100 [03:43<04:58,  4.20s/it]2026-06-07 10:46:52.198533: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:46:52.386630: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:01.099365: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:01.374658: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  32%|███▏      | 32/100 [04:02<05:29,  4.84s/it]2026-06-07 10:47:10.785486: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:10.951761: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:11.114141: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:12.556690: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:12.795476: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:14.043024: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:14.225163: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:15.972471: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:16.194543: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:26.240470: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:26.602440: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:30.125472: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:30.515966: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,1552,2040]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,1552,2040]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-07 10:47:30.526946: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:30.582227: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.066364376s
# Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,1552,2040]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,1552,2040]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
#  34%|███▍      | 34/100 [04:31<09:29,  8.62s/it]2026-06-07 10:47:39.288207: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:39.454572: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:40.988800: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:41.236419: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:42.544348: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:42.729260: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:44.574234: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:44.801929: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:55.477862: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:55.848017: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:59.421990: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:59.794695: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,2040,1624]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,2040,1624]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-07 10:47:59.829323: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:47:59.883415: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.088821698s
# Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,2040,1624]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,2040,1624]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
#  43%|████▎     | 43/100 [05:20<03:21,  3.53s/it]2026-06-07 10:48:28.441509: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:28.600570: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:28.757119: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:29.897872: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:30.123726: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:31.207279: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:31.380744: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:32.753560: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:32.964756: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:41.978333: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:42.309098: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:45.729731: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:46.098039: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  45%|████▌     | 45/100 [05:46<06:54,  7.54s/it]2026-06-07 10:48:54.936374: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:55.094961: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:55.254792: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:56.584835: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:56.812222: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:58.018054: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:58.194766: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:59.658192: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:48:59.873081: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:09.440812: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:09.772422: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:13.190964: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:13.557876: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  50%|█████     | 50/100 [06:22<04:16,  5.14s/it]2026-06-07 10:49:30.056874: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:30.215110: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:31.456791: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:31.680206: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:32.702720: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:32.876394: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:34.397700: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:34.608211: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:43.467225: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:43.797152: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:47.084588: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:47.446511: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  51%|█████     | 51/100 [06:44<08:23, 10.28s/it]2026-06-07 10:49:53.255208: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:49:53.468258: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:06.050218: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:06.381439: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  53%|█████▎    | 53/100 [07:05<07:37,  9.73s/it]2026-06-07 10:50:14.052016: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:14.257435: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:26.089458: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:26.405539: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  54%|█████▍    | 54/100 [07:22<09:07, 11.90s/it]2026-06-07 10:50:30.637538: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:30.812702: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:32.665227: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:32.935990: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:34.622561: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:34.820257: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:36.734288: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:36.979184: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:49.601638: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:50.020241: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:50:50.069022: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.55 = (f32[1,64,1020,1020]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,192,1020,1020]{3,2,1,0} %bitcast.1147, f32[64,192,3,3]{3,2,1,0} %bitcast.1154, f32[64]{0} %bitcast.1156), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_25_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-07 10:50:50.187138: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.118303202s
# Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.55 = (f32[1,64,1020,1020]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,192,1020,1020]{3,2,1,0} %bitcast.1147, f32[64,192,3,3]{3,2,1,0} %bitcast.1154, f32[64]{0} %bitcast.1156), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_25_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-07 10:50:54.442771: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# ...
# 2026-06-07 10:54:02.147547: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:02.201984: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.208617463s
# Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,1872,2040]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,1872,2040]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-07 10:54:03.202202: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng11{k2=1,k3=0} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,1872,2040]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,1872,2040]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-07 10:54:03.313469: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.111363589s
# Trying algorithm eng11{k2=1,k3=0} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,1872,2040]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,1872,2040]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
#  80%|████████  | 80/100 [11:03<04:12, 12.64s/it]2026-06-07 10:54:11.855107: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:12.010155: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:13.186980: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:13.405091: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:14.309394: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:14.479919: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:15.916104: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:16.124078: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:24.446047: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:24.766457: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:27.852120: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:28.200954: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  82%|████████▏ | 82/100 [11:27<03:25, 11.44s/it]2026-06-07 10:54:35.658395: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:35.817171: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:37.121876: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:37.349219: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:38.540434: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:38.717260: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:40.072239: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:40.287580: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:49.721298: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:50.061557: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:53.239858: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:54:53.610025: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  90%|█████████ | 90/100 [12:09<00:36,  3.69s/it]2026-06-07 10:55:17.226852: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:17.394516: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:17.559752: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:19.088166: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:19.333878: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:20.742752: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:20.928540: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:22.667370: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:22.893583: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:33.814111: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:34.187261: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:37.912357: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:38.265228: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,2040,1672]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,2040,1672]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-07 10:55:38.332929: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 10:55:38.388229: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.123102235s
# Trying algorithm eng13{} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,2040,1672]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,2040,1672]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-07 10:55:39.388497: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng11{k2=1,k3=0} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,2040,1672]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,2040,1672]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-06-07 10:55:39.417186: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.028862922s
# Trying algorithm eng11{k2=1,k3=0} for conv %cudnn-conv-bias-activation.57 = (f32[1,32,2040,1672]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,96,2040,1672]{3,2,1,0} %bitcast.1206, f32[32,96,3,3]{3,2,1,0} %bitcast.1213, f32[32]{0} %bitcast.1215), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="functional_1_1/conv2d_27_1/convolution" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 100%|██████████| 100/100 [13:01<00:00,  7.82s/it]
# CSV salvato in: /kaggle/working/n2n_saltpepper_amount005_outputs/div2k_valid/div2k_valid_saltpepper_amount005_n2n_metrics.csv
# PSNR medio clean/noisy: 17.759975643748785
# PSNR medio clean/N2N: 32.20618813120318
# Gain PSNR medio: 14.446212487454392
# SSIM medio clean/noisy: 0.3903299982845783
# SSIM medio clean/N2N: 0.9010878336429596
# Gain SSIM medio: 0.510757836997509
